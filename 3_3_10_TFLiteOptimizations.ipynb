# %% [markdown]
# <a href="https://colab.research.google.com/github/Miguel231/Computing-Acceleration/blob/main/3_3_10_TFLiteOptimizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cats versus Dogs
# Exploring optimization impact on size, performance and accuracy!
#
# **For best performance on this Colab make sure you are using a GPU runtime!** The runtime can be changed by selecting: ```runtime -> change runtime type``` and selecting GPU from the hardware accelerator dropdown.

# %% [markdown]
# ### We start by importing TensorFlow and our Dataset
# And splitting our dataset into batches.

# %%
# !pip install -q tensorflow tensorflow-hub==0.16.1 tensorflow-datasets==4.9.4 protobuf==4.25.3

# %%
# !pip install -U ml_dtypes>=0.5.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.3 which is incompatible.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, but you have tf-keras 2.17.0 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tf_keras~=2.19, but you have tf-keras 2.17.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %%
import numpy as np
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

# format images to have normalized pixels
def format_image(image, label):
    image = tf.image.resize(image, (224, 224)) / 255.0
    return  image, label

# load in our dataset
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

# display how much data we have
num_examples = metadata.splits['train'].num_examples
num_classes = metadata.features['label'].num_classes
print(num_examples)
print(num_classes)

# split the data in training, validation, and test datasets
BATCH_SIZE = 32
train_batches = raw_train.shuffle(num_examples // 4).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = raw_validation.map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = raw_test.map(format_image).batch(1)

# display the shape of our data
for image_batch, label_batch in train_batches.take(1):
    pass
image_batch.shape
# Out:
# 23262
# 2
# TensorShape([32, 224, 224, 3])

# %% [markdown]
# ### We next define our (pre-trained) model

# %%
module_selection = ("mobilenet_v2", 224, 1280)
handle_base, pixels, FV_SIZE = module_selection
MODULE_HANDLE = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/5"
IMAGE_SIZE = (pixels, pixels)
print("Using {} with input size {} and output dimension {}".format(MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))

feature_extractor = hub.KerasLayer(MODULE_HANDLE,
                                   input_shape=IMAGE_SIZE + (3,),
                                   output_shape=[FV_SIZE],
                                   trainable=False)

print("Building model with", MODULE_HANDLE)

model = tf.keras.Sequential([
        tf.keras.layers.Lambda(lambda x: feature_extractor(x)), # Wrap the hub layer in a Lambda layer
        tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Using https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/5 with input size (224, 224) and output dimension 1280
# Building model with https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/5
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### We then train and save our model
# Since we are doing transfer learning to fine tune a pre-trained model to our dataset we only need to use 5 Epochs. We will explore transfer learning in detail and study how, why, and where it works later in this course!

# %%
EPOCHS = 5

hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches)
# Out:
# Epoch 1/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 575s 965ms/step - accuracy: 0.9552 - loss: 0.1096 - val_accuracy: 0.9841 - val_loss: 0.0475
# Epoch 2/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 615s 959ms/step - accuracy: 0.9886 - loss: 0.0331 - val_accuracy: 0.9858 - val_loss: 0.0405
# Epoch 3/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 611s 939ms/step - accuracy: 0.9893 - loss: 0.0288 - val_accuracy: 0.9867 - val_loss: 0.0412
# Epoch 4/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 496s 842ms/step - accuracy: 0.9913 - loss: 0.0234 - val_accuracy: 0.9871 - val_loss: 0.0409
# Epoch 5/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 494s 827ms/step - accuracy: 0.9931 - loss: 0.0203 - val_accuracy: 0.9858 - val_loss: 0.0435

# %%
"""CATS_VS_DOGS_SAVED_MODEL = "exp_saved_model"
tf.saved_model.save(model, CATS_VS_DOGS_SAVED_MODEL)
"""

CATS_VS_DOGS_SAVED_MODEL = 'saved_model/1'
model.export(CATS_VS_DOGS_SAVED_MODEL)  # <-- This replaces tf.saved_model.save or model.save for SavedModel
# Out:
# Saved artifact at 'saved_model/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   138230809857488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374818448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809772112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809857296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986120912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986117840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809778640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809786704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809857104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374815952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986124176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374818640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986121104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809778448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986126096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809783632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374816144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374815760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809772880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374812496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809786512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374812304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809780944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374808464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374811152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809786320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809860176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809856912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374823248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374823056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809781328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374808272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986121296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374820176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809788240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809783440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374818256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374821328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809780752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986124368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374809808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374808080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374807888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986121488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374822864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809776336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374821712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809783248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374818064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986122832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986121680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809855184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809780368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374816336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809776144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986115536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809788048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809856720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986120720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374821520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809786128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374818832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986125904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809772304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986119760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809787856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809782864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986124560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809856528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809778256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809787664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809856336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374807504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374807312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374822672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809858256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374812112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374807120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809856144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374817872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809785936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809787472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986119952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986124752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809787280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374813840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374821136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809782672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374811920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374815568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809773840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374822480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809780176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986117072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374820944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374822288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809778064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374811728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374809616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809775952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809855952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374822096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986117264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986121872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374815376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809787088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809777872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809777680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809785744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809775760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986122064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374815184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809855760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809785552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809775568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809785360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809777488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986120528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374817680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986116496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986125136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374817488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986125328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809773648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809776720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809859024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809777296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374817296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374813648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809858064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986120144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809782288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374814608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986117456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986122256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374813456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374817104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809773264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374816720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809786896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809775184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986126480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809779024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809782096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374811536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374809232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986125712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809777104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986126288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374810000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809781136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374819024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374811344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986126672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809774992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374809040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809858448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986122448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986118992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809773072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986119184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809857872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374813264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986119376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809781904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374808848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986125520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374809424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374813072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809855568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374816528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809781712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809785168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809858832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986120336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809783824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374812880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809781520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809784976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986116880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809855376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986116688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374820752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809778832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809772688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374821904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986122640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374808656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374820560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809857680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986116112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986123792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374820368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809858640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374816912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809854608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986119568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231374812688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986117648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138231986115728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138230809867856: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# ### Your task starts here:
# + Run this code, and you'll have model1.tflite, with no optimization or quantization
#
# + Then, remove the comment on the ```converter.optimizations = []``` line. Change the model name to model2.tflite, and rerun. Model2.tflite will now have optimizations added -- you should see a much smaller file size.
#
# + Finally, remove the comments on the code to add a representative dataset and set the supported ops as shown. Change the model name to model3.tflite, and rerun. Model3.tflite will now have optimizations added, along with quantization from the representative dataset. Note: it might be slightly larger than model2.tflite!
#
#
# **Note:** tf.lite.Optimize has changed and the OPTIMIZE_FOR_SIZE and OPTIMIZE_FOR_LATENCY options are now deprecated and are the same and DEFAULT: https://www.tensorflow.org/api_docs/python/tf/lite/Optimize

# %%
import pathlib
converter = tf.lite.TFLiteConverter.from_saved_model(CATS_VS_DOGS_SAVED_MODEL)

# These options are for converter optimizaitons
# Consider trying the converter without them and
# explore model size and accuracy
# Then...use them and reconvert the model and explore model
# size an accuracy at that point. What differences do you see?

converter.optimizations = [tf.lite.Optimize.DEFAULT]    # Uncomment this line for Model 2 and Model 3

def representative_data_gen():                          # Uncomment the following 5 lines for Model 3
     for input_value, _ in test_batches.take(100):
         yield [input_value]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

tflite_model = converter.convert()
tflite_models_dir = pathlib.Path("/tmp/")

tflite_model_file = tflite_models_dir/'model3.tflite'     # Change the filename here for Model2 and Model3!
tflite_model_file.write_bytes(tflite_model)


# Without any optimizations I got
# 8857848  (model1.tflite)
# With the .optimizations property set I got
# 2629648 (model2.tflite)
# With the .optimizations property and representative data set I got
# 2835952 -- Slightly larger!  (model3.tflite)
# Out:
# 2713408

# %% [markdown]
# Model 1: 8875644
#
# Model 2: 2510048
#
# Model 3: 2713408

# %% [markdown]
# ### Your task continues
# Now we will test the accuracy of the three models! After you run each model you will get the number of correct predictions and then you can plot which images were correct/incorrect!
# + Run this code
# + Change the model file to model2.tflite and run it again
# + Change the model file to model3.tflite and run it again

# %%
#@title Run this cell each time to test your model's accuracy (make sure to change the filename)
from tqdm import tqdm
# Load TFLite model and allocate tensors.
tflite_model_file = '/tmp/model3.tflite'                 # Change the filename here for Model 2 and 3
interpreter = tf.lite.Interpreter(model_path=tflite_model_file)
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

predictions = []

test_labels, test_imgs = [], []
for img, label in tqdm(test_batches.take(100)):
    interpreter.set_tensor(input_index, img)
    interpreter.invoke()
    predictions.append(interpreter.get_tensor(output_index))

    test_labels.append(label.numpy()[0])
    test_imgs.append(img)

# For model 1, I got 32.25 it/s
# For model 2, I got 16.16 it/s
# For model 3, I got 1.19s it/s
# Note: since the it/s will depend on the computer on which your Colab VM
#       instance is running -- we would expect it to vary a bit.
# Note2: Changes have been made to the TFLite Interpreter since Laurence filmed the
#        previous video that further optimize it for mobile use at the expense of
#        speed in Colab. As such, you'll find that while Laurence was able to achieve
#        16 it/s for model 2, you may only see speeds of 1-2 it/s

score = 0
for item in range(0,100):
  prediction=np.argmax(predictions[item])
  label = test_labels[item]
  if prediction==label:
    score=score+1

print("Out of 100 predictions I got " + str(score) + " correct")

# Model 1 - 100 Correct
# Model 2 - 99 Correct
# Model 3 - 99 Correct
# Note: since training starts from a random intialization it would not be
#       surprising if your result is off by 1 or 2 correct.
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 64.30it/s]
# Out of 100 predictions I got 99 correct

# %% [markdown]
# Model 1: 100%|██████████| 100/100 [00:01<00:00, 82.29it/s]Out of 100 predictions I got 100 correct
#
# Model 2: 100%|██████████| 100/100 [00:03<00:00, 29.44it/s]Out of 100 predictions I got 100 correct
#
#
# Model 3: 100%|██████████| 100/100 [00:01<00:00, 64.30it/s]Out of 100 predictions I got 99 correct

# %%
#@title Define utility functions once for plotting
# Utilities for plotting

class_names = ['cat', 'dog']

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    img = np.squeeze(img)

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)

    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                         100*np.max(predictions_array),
                                         class_names[true_label]), color=color)

# %%
#@title Visualize the outputs each time { run: "auto" }
max_index = 24 #@param {type:"slider", min:1, max:100, step:1}
for index in range(0,max_index):
  plt.figure(figsize=(6,3))
  plt.subplot(1,2,1)
  plot_image(index, predictions, test_labels, test_imgs)
  plt.show()
